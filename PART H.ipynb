# %% [markdown]
# # Part H – Final Analysis & Reporting

# %% [markdown]
# # Part H – Final Analysis & Reporting
#
# ## 1. Final Report Summary
#
# The objective of this project was to develop and evaluate multiple regression models for predicting house prices using the Advanced House Price Dataset.
#
# The following models were implemented:
#
# * Ridge Regression
# * Lasso Regression
# * Decision Tree Regressor
# * Random Forest Regressor
# * Linear SVR
# * RBF SVR
#
# Each model was evaluated using:
#
# * RMSE (Root Mean Squared Error)
# * MAE (Mean Absolute Error)
# * R² Score
#
# Cross-validation and regularization techniques were also applied to improve model reliability and reduce overfitting.
#
# ---

# %% [markdown]
# ## 3. Impact of Regularization
#
# ### Ridge Regression
#
# * Reduced coefficient magnitude
# * Improved model stability
# * Controlled overfitting
#
# ### Lasso Regression
#
# * Reduced coefficient magnitude
# * Performed automatic feature selection
# * Improved model interpretability
#
# ---

# %% [markdown]
# ## 4. Role of Cross Validation
#
# Cross-validation was used to:
#
# * Estimate model performance reliably
# * Reduce overfitting risk
# * Improve model selection
# * Tune hyperparameters effectively
#
# Methods used:
#
# * K-Fold Cross Validation
# * Stratified K-Fold
# * Leave-One-Out CV
# * Time Series Split
#
# ---

# %%
feature_importance = pd.DataFrame({

    'Feature': X.columns,
    'Importance': rf.feature_importances_

})

feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

print(feature_importance)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.barh(
    feature_importance['Feature'],
    feature_importance['Importance']
)

plt.xlabel("Importance Score")
plt.ylabel("Features")

plt.title("Feature Importance Analysis")

plt.show()

# %% [markdown]
# ## 7. Business Interpretation
#
# The developed model can help:
#
# * Predict house prices accurately
# * Assist real estate companies
# * Improve investment decisions
# * Support property valuation
# * Reduce pricing errors
#
# The model can be integrated into real-estate applications for automated price prediction.
#
# ---

# %% [markdown]
# ## 8. Final Conclusion
#
# ### Conclusion
#
# This project successfully implemented multiple regression techniques for house price prediction. Data preprocessing, feature engineering, regularization, cross-validation, and model evaluation were performed systematically.
#
# Among all models, **Random Forest Regressor** achieved the best performance due to its ability to capture complex non-linear relationships while reducing overfitting through ensemble learning.
#
# Regularization techniques such as Ridge and Lasso improved model stability, while cross-validation ensured reliable performance evaluation.
#
# Therefore, **Random Forest Regressor is recommended as the final production model for house price prediction because it provides the highest accuracy, lowest prediction error, and strongest generalization performance.**
#
# ---
